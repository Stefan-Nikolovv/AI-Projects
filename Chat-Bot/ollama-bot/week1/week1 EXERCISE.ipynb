# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import requests
from IPython.display import Markdown, display, update_display
# from openai import OpenAI
import ollama

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Type your question that you need to be answerd 
my_question = input("Please enter your question:")
# Out:
# Please enter your question: i have an Audi a6 c6 4f and my turbo at low rpm not providing enough boost software want a 1.5bar but my turbo provides an 0.6 to 0.7 bar

# %%
# prompts

system_prompt = "You are a helpful technical tutor who answers questions about python code, software engineering, data science and LLMs"
user_prompt = "Please give a detailed explanation to the following question: " + my_question

# %%
# messages

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# %%
# Get Llama 3.2 to answer
response = ollama.chat(model=MODEL_LLAMA, messages=messages)
reply = response['message']['content']
display(Markdown(reply))
# Out:
# A question that combines automotive engineering with Python programming!
#
# **Context:** You're the owner of an Audi A6 C6 (4F) and are experiencing issues with your turbocharger not providing enough boost at low RPMs. Your goal is to increase the boost pressure from 0.6-0.7 bar to 1.5 bar, despite the turbo's maximum achievable pressure being around 0.6-0.7 bar.
#
# **Understanding Turbo Boost Pressure:**
#
# Boost pressure is a measure of the air pressure added to an engine's intake system by the turbocharger. In your case, you want to increase this boost pressure to optimize performance. However, there are limitations imposed by the turbocharger itself, which can be influenced by various factors, such as:
#
# 1. **Turbocharging efficiency:** The design and materials used in the turbocharger affect its ability to compress air.
# 2. **Wastegate actuation:** The wastegate is a valve that opens when boost pressure exceeds a set point, allowing excess gas to escape. Proper wastegate actuation is crucial for efficient boost management.
#
# **Software Solution:**
#
# To increase boost pressure from 0.6-0.7 bar to 1.5 bar, you'll need to use software manipulation. This involves modifying the engine's control unit (ECU) settings or using a standalone tuning tool to adjust various parameters that affect turbo boost pressure.
#
# Here are some potential software solutions:
#
# ### 1. Tuner Software (e.g., Megasquirt, ECU Reflashing)
#
# You can use a tuner software like Megashift or MegaSquirt to reflashing the engine's ECU (Engine Control Unit) with new calibration settings. This will allow you to increase boost pressure and adjust other parameters to optimize performance.
#
# For example, you could:
#
# * Increase **Boost Pressure** (BP) in the ECU map
# * Adjust **Wastegate Actuation** (WA) to improve boost holding at higher pressures
# * Modify **Turbocharger Inlet Temperature** (TIT) to optimize turbo efficiency
#
# Keep in mind that reflashing the ECU will require technical knowledge and can be complex. It's essential to consult a professional if you're not experienced with ECU tuning.
#
# ### 2. Standalone Tuning Tools (e.g., OpenECU, ECutek)
#
# Standalone tuning tools provide a user-friendly interface for adjusting various engine parameters without requiring reflashing the ECU. These tools use proprietary protocols to interact with the engine's ECU and allow you to tweak settings remotely.
#
# For example, you could:
#
# * Adjust **Boost Pressure** (BP) in the OpenECU Tuner
# * Fine-tune **Wastegate Actuation** (WA) using the ECutek Tuning Tool
# * Optimize **Turbocharger Inlet Temperature** (TIT) for improved efficiency
#
# These tools often require a subscription or one-time payment, and may not offer all the features of reflashing the ECU.
#
# ### 3. Engine Management System (EMS) Upgrades
#
# If you're willing to invest in more extensive modifications, you can consider upgrading your engine management system (EMS). This involves replacing the existing EMS with a more advanced system that provides more control over boost pressure and other engine parameters.
#
# For example, you could install an EMS like the Xtrac VCS-1000 or the AWE Tuning EMF. These systems offer advanced tuning capabilities and can provide more precise control over boost pressure.
#
# **Python Code**
#
# While there isn't any Python code that directly solves your turbocharger issue, I can provide some example Python scripts to illustrate how you might approach this problem:
#
# 1. **Boost Pressure Calculator:**
# ```python
# import numpy as np
#
# def calculate_boost_pressure(turbo_max_pressure, waste_gate actuation):
#     """
#     Calculate the maximum boost pressure achievable by the turbocharger.
#
#     Parameters:
#     - turbo_max_pressure (float): The maximum boost pressure achieved by the turbocharger.
#     - waste_gate actuation (float): The wastegate actuation percentage.
#
#     Returns:
#     - float: The calculated boost pressure.
#     """
#     # Assume a linear relationship between boost pressure and wastegate actuation
#     return turbo_max_pressure * (1 - (waste_gate_actuation / 100))
#
# # Example usage
# turbo_max_pressure = 0.7
# waste_gate_actuation = 50
#
# boost_pressure = calculate_boost_pressure(turbo_max_pressure, waste_gate_actuation)
# print(f"Calculated boost pressure: {boost_pressure} bar")
# ```
# This script calculates the maximum boost pressure achievable by the turbocharger based on its design and wastegate actuation. Keep in mind that this is a simplified example and actual calculations may be more complex.
#
# 2. **Turbocharger Efficiency Model:**
# ```python
# import numpy as np
#
# def calculate_turbo_efficiency(turbine_temp, compressor_temp):
#     """
#     Calculate the turbocharger efficiency based on turbine and compressor temperatures.
#
#     Parameters:
#     - turbine_temp (float): The turbine inlet temperature.
#     - compressor_temp (float): The compressor inlet temperature.
#
#     Returns:
#     - float: The calculated turbocharger efficiency.
#     """
#     # Assume a simple exponential relationship between turbine and compressor temperatures
#     return np.exp((turbine_temp - compressor_temp) / 100)
#
# # Example usage
# turbine_temp = 400
# compressor_temp = 300
#
# turbo_efficiency = calculate_turbo_efficiency(turbine_temp, compressor_temp)
# print(f"Calculated turbocharger efficiency: {turbo_efficiency}")
# ```
# This script calculates the turbocharger efficiency based on turbine and compressor temperatures. This is a simplified example, but it illustrates how you might approach optimizing turbo performance.
#
# **Conclusion**
#
# Increasing boost pressure from 0.6-0.7 bar to 1.5 bar requires careful consideration of various factors, including turbocharging efficiency, wastegate actuation, and engine management system settings. While Python code can provide a starting point for calculations and simulations, actual modifications require technical expertise and professional guidance.
#
# If you're not familiar with ECU tuning or engine management systems, it's essential to consult a professional tuner who can help you optimize your Audi A6 C6 (4F) for maximum performance and safety.
