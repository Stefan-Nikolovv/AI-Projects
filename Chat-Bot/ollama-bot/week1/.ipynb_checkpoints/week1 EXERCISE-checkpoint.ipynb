# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import requests
from IPython.display import Markdown, display, update_display
# from openai import OpenAI
import ollama

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Type your question that you need to be answerd 
my_question = input("Please enter your question:")
# Out:
# Please enter your question: i have problem with low pressure at my turbo my motor is 2.0 tdi audi engine at low rpm dont have enough boost but after that 2000 rpm have full power where to look for a problem

# %%
# prompts

# customprompts

system_prompt = "You are a helpful technical mechanic that provide some info about problem with turbocharges"
user_prompt = "Please give a detailed explanation to the following question: " + my_question

# system_prompt = "You are a helpful technical tutor who answers questions about python code, software engineering, data science and LLMs"
# user_prompt = "Please give a detailed explanation to the following question: " + my_question

# %%
# messages

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# %%
# Get Llama 3.2 to answer
response = ollama.chat(model=MODEL_LLAMA, messages=messages)
reply = response['message']['content']
display(Markdown(reply))
# Out:
# I'll help you diagnose the issue with your Audi 2.0 TDI engine's turbocharger.
#
# **Understanding Turbocharger Behavior**
#
# A turbocharger is a turbine-driven forced induction device that compresses air into an internal combustion engine to increase power and efficiency. The basic operation of a turbocharger involves:
#
# 1. **Boost Pressure**: As the turbine spins, it drives the compressor to compress air.
# 2. **Wastegate Operation**: The wastegate allows excess boost pressure to be released, preventing damage to the engine or turbocharger.
#
# **Symptoms and Possible Causes**
#
# You've noticed that at low RPMs (e.g., 0-2000 RPM), there is not enough boost pressure, but as you increase RPM, power increases. This behavior could indicate several issues:
#
# 1. **Low Boost Pressure**: Insufficient boost pressure can be caused by:
# 	* Faulty or clogged wastegate
# 	* Incorrect wastegate settings (e.g., too small a valve)
# 	* Clogged or dirty turbocharger inlet and outlet
# 	* Faulty turbocharger bearings or shaft seals
# 2. **Turbocharger Turbine Failure**: A faulty turbine can cause the turbo to not spin properly, leading to low boost pressure.
# 3. **Compressor Problems**: Compressor issues can lead to reduced airflow and lower boost pressures at low RPMs.
# 4. **Engine Oil Issues**: Low engine oil levels or poor engine oil quality can lead to premature bearing wear on the turbocharger bearings.
#
# **Where to Look for the Problem**
#
# To diagnose the issue, focus on the following areas:
#
# 1. **Wastegate**: Check if the wastegate is functioning correctly. Inspect the wastegate valve and ensure it's not clogged or faulty.
# 2. **Boost Pressure Gauge**: Check the boost pressure gauge at low RPMs to determine if the turbocharger is indeed producing sufficient boost.
# 3. **Turbocharger Oil Level and Quality**: Ensure the engine oil level is adequate, and consider having a oil analysis performed to check for contamination or excessive wear on the turbocharger bearings.
# 4. **Compressor and Turbine**: Inspect the compressor and turbine for any signs of damage, wear, or fouling.
# 5. **Turbocharger Inlet and Outlet**: Check if the turbocharger inlet and outlet are clogged or dirty. A clean air filter and fuel injectors will also help.
# 6. **ECU Settings**: Consult your Audi's owner's manual to see if there are any specific settings for boost pressure at low RPMs.
#
# **Additional Diagnostic Steps**
#
# To further diagnose the issue, consider:
#
# 1. **Visual Inspection**: Use a flashlight or lamp to inspect the turbocharger and its components under the hood.
# 2. **Scan Tool Data**: Connect your Audi's scan tool (e.g., Audi A3x or equivalent) to monitor boost pressure, engine oil levels, and other relevant data at different RPM ranges.
# 3. **Turbocharger Pressure Test**: Perform a pressure test on the turbocharger using specialized equipment.
#
# Remember that a professional mechanic with experience in turbocharged engines is recommended for proper diagnosis and repair.
