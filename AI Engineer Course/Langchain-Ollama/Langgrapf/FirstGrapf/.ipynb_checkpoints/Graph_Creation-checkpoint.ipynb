# %%
# %load_ext mypy_ipython

# %%
from langgraph.graph import START, END, StateGraph
from typing_extensions import TypedDict
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage, BaseMessage
from langchain_core.runnables import Runnable
from collections.abc import Sequence
from typing import Literal

# %%
class State (TypedDict):
    messages: Sequence[BaseMessage]

# %%
state = State(messages = [HumanMessage("Could you tell me what is better an Audi a6 or BMW 5 series?")])

# %%
state
# Out:
# {'messages': [HumanMessage(content='Could you tell me what is better an Audi a6 or BMW 5 series?', additional_kwargs={}, response_metadata={})]}

# %%
state['messages'][0].content
# Out:
# 'Could you tell me what is better an Audi a6 or BMW 5 series?'

# %%
chat = ChatOllama( model= 'llama3.2',seed=365, temperature=0, num_predict=256)

# %%
response = chat.invoke(state['messages'])

# %%
response
# Out:
# AIMessage(content='Both the Audi A6 and BMW 5 Series are excellent luxury sedans, but which one is "better" ultimately depends on your personal preferences, needs, and priorities. Here\'s a comparison of the two:\n\n**Design and Features**\n\n* Audi A6: The A6 has a more angular and aggressive design, with a focus on aerodynamics and a sporty stance. It also features a more modern and minimalist interior design.\n* BMW 5 Series: The 5 Series has a more traditional and conservative design, with a focus on comfort and practicality. Its interior is often described as more luxurious and refined.\n\n**Performance**\n\n* Audi A6: The A6 offers a range of engine options, including a 3.0L turbocharged V6 that produces up to 335 horsepower.\n* BMW 5 Series: The 5 Series also offers a range of engine options, including a 3.0L turbocharged inline-6 that produces up to 523 horsepower.\n\n**Handling and Ride**\n\n* Audi A6: The A6 is known for its sporty handling and responsive steering, making it a joy to drive on twisty roads.\n* BMW 5 Series: The 5 Series has a reputation for being one of the most comfortable and', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2025-09-30T14:25:31.851781Z', 'done': True, 'done_reason': 'length', 'total_duration': 5820907875, 'load_duration': 92220291, 'prompt_eval_count': 42, 'prompt_eval_duration': 654373958, 'eval_count': 256, 'eval_duration': 5073828792, 'model_name': 'llama3.2'}, id='run--b51663f5-77b4-4789-87d6-ac61eeafa1e0-0', usage_metadata={'input_tokens': 42, 'output_tokens': 256, 'total_tokens': 298})

# %%
def ask_question(state: State) -> State:
    print(f"\n --------> ENTERING ask_question:")
     print("What is your question?")
     return State(messages = [HumanMessage(input())])

# %%
def chatbot(state: State) -> State:

    print(f"\n --------> ENTERING chatbot:")
    
    response = chat.invoke(state['messages'])
    response.pretty_print()
    return State(messages = [response])

# %%
chatbot(state)
# Out:
#  --------> ENTERING chatbot:
# ================================== Ai Message ==================================
#
# Both the Audi A6 and BMW 5 Series are excellent luxury sedans, but which one is "better" ultimately depends on your personal preferences, needs, and priorities. Here's a comparison of the two:
#
# **Design and Features**
#
# * Audi A6: The A6 has a more angular and aggressive design, with a focus on aerodynamics and a sporty stance. It also features a more modern and minimalist interior design.
# * BMW 5 Series: The 5 Series has a more traditional and conservative design, with a focus on comfort and practicality. Its interior is often described as more luxurious and refined.
#
# **Performance**
#
# * Audi A6: The A6 offers a range of engine options, including a 3.0L turbocharged V6 that produces up to 335 horsepower.
# * BMW 5 Series: The 5 Series also offers a range of engine options, including a 3.0L turbocharged inline-6 that produces up to 523 horsepower.
#
# **Handling and Ride**
#
# * Audi A6: The A6 is known for its sporty handling and responsive steering, making it a joy to drive on twisty roads.
# * BMW 5 Series: The 5 Series has a reputation for being one of the most comfortable and
# {'messages': [AIMessage(content='Both the Audi A6 and BMW 5 Series are excellent luxury sedans, but which one is "better" ultimately depends on your personal preferences, needs, and priorities. Here\'s a comparison of the two:\n\n**Design and Features**\n\n* Audi A6: The A6 has a more angular and aggressive design, with a focus on aerodynamics and a sporty stance. It also features a more modern and minimalist interior design.\n* BMW 5 Series: The 5 Series has a more traditional and conservative design, with a focus on comfort and practicality. Its interior is often described as more luxurious and refined.\n\n**Performance**\n\n* Audi A6: The A6 offers a range of engine options, including a 3.0L turbocharged V6 that produces up to 335 horsepower.\n* BMW 5 Series: The 5 Series also offers a range of engine options, including a 3.0L turbocharged inline-6 that produces up to 523 horsepower.\n\n**Handling and Ride**\n\n* Audi A6: The A6 is known for its sporty handling and responsive steering, making it a joy to drive on twisty roads.\n* BMW 5 Series: The 5 Series has a reputation for being one of the most comfortable and', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2025-09-30T14:25:37.080956Z', 'done': True, 'done_reason': 'length', 'total_duration': 5184985958, 'load_duration': 82223792, 'prompt_eval_count': 42, 'prompt_eval_duration': 21824125, 'eval_count': 256, 'eval_duration': 5080454416, 'model_name': 'llama3.2'}, id='run--2a3c886c-80dd-4066-bc1e-224f74005008-0', usage_metadata={'input_tokens': 42, 'output_tokens': 256, 'total_tokens': 298})]}

# %%
graph = StateGraph(State)

# %%
graph.add_node('chatbot', chatbot)
graph.add_edge(START, "chatbot")
graph.add_edge('chatbot', END)

# %%
graph_compiled = graph.compile()

# %%
isinstance(graph_compiled, Runnable)
# Out:
# True

# %%
isinstance(graph, Runnable)
# Out:
# False

# %%
graph_compiled.invoke(state)
# Out:
#  --------> ENTERING chatbot:
# ================================== Ai Message ==================================
#
# Both the Audi A6 and BMW 5 Series are excellent luxury sedans, but which one is "better" ultimately depends on your personal preferences, needs, and priorities. Here's a comparison of the two:
#
# **Design and Features**
#
# * Audi A6: The A6 has a more angular and aggressive design, with a focus on aerodynamics and a sporty stance. It also features a more modern and minimalist interior design.
# * BMW 5 Series: The 5 Series has a more traditional and conservative design, with a focus on comfort and practicality. Its interior is often described as more luxurious and refined.
#
# **Performance**
#
# * Audi A6: The A6 offers a range of engine options, including a 3.0L turbocharged V6 that produces up to 335 horsepower.
# * BMW 5 Series: The 5 Series also offers a range of engine options, including a 3.0L turbocharged inline-6 that produces up to 523 horsepower.
#
# **Handling and Ride**
#
# * Audi A6: The A6 is known for its sporty handling and responsive steering, making it a joy to drive on twisty roads.
# * BMW 5 Series: The 5 Series has a reputation for being one of the most comfortable and
# {'messages': [AIMessage(content='Both the Audi A6 and BMW 5 Series are excellent luxury sedans, but which one is "better" ultimately depends on your personal preferences, needs, and priorities. Here\'s a comparison of the two:\n\n**Design and Features**\n\n* Audi A6: The A6 has a more angular and aggressive design, with a focus on aerodynamics and a sporty stance. It also features a more modern and minimalist interior design.\n* BMW 5 Series: The 5 Series has a more traditional and conservative design, with a focus on comfort and practicality. Its interior is often described as more luxurious and refined.\n\n**Performance**\n\n* Audi A6: The A6 offers a range of engine options, including a 3.0L turbocharged V6 that produces up to 335 horsepower.\n* BMW 5 Series: The 5 Series also offers a range of engine options, including a 3.0L turbocharged inline-6 that produces up to 523 horsepower.\n\n**Handling and Ride**\n\n* Audi A6: The A6 is known for its sporty handling and responsive steering, making it a joy to drive on twisty roads.\n* BMW 5 Series: The 5 Series has a reputation for being one of the most comfortable and', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2025-09-30T14:25:42.321799Z', 'done': True, 'done_reason': 'length', 'total_duration': 5186216708, 'load_duration': 79031625, 'prompt_eval_count': 42, 'prompt_eval_duration': 23851833, 'eval_count': 256, 'eval_duration': 5082860750, 'model_name': 'llama3.2'}, id='run--e0d5433a-063d-4544-a80d-67674f7e3798-0', usage_metadata={'input_tokens': 42, 'output_tokens': 256, 'total_tokens': 298})]}

# %%
# %mypy
# Out:
# Success: no issues found in 1 source file
# Type checking successful

# %% [markdown]
# ## Conditional Edges and Routings
