# %%
# %load_ext mypy_ipython
# Out:
# The mypy_ipython extension is already loaded. To reload it, use:
#   %reload_ext mypy_ipython

# %%
from langgraph.graph import START, END, StateGraph, add_messages
from typing_extensions import TypedDict
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage, BaseMessage, AIMessage
from langchain_core.runnables import Runnable
from collections.abc import Sequence
from typing import Literal, Annotated

# %% [markdown]
# # The Annotated Construct and Reducer Function

# %% [markdown]
# ## Using add_messages Function

# %%
my_list = add_messages()

# %% [markdown]
# ## Define State

# %%
class State(TypedDict):
    messages: Annotated[Sequence[BaseMessage], add_messages]

# %% [markdown]
# ## Define Nodes

# %%
chat = ChatOllama( model= 'llama3.2',seed=365, temperature=0, num_predict=256)

# %%
def ask_question(state: State) -> State:
     print(f"\n --------> ENTERING ask_question:")
     for i in state['messages']:
        i.pretty_print()
        
     question = "What is your question?"

     return State(messages = [AIMessage(question) ,HumanMessage(input())])

# %%
def ask_another_question(state: State) -> State:
     print(f"\n --------> ENTERING ask_another_question:")
     for i in state['messages']:
        i.pretty_print()
     question = "Would you like to ask one more question (yes/no)?"
     return State(messages = [AIMessage(question) ,HumanMessage(input())])

# %%
def chatbot(state: State) -> State:

    print(f"\n --------> ENTERING chatbot:")
    for i in state['messages']:
        i.pretty_print()
    response = chat.invoke(state['messages'])
    response.pretty_print()
    return State(messages = [response])

# %% [markdown]
# ### Routing Function

# %%
def routing_function(state: State) -> Literal['ask_question', "__end__"]:
    if state['messages'][-1].content == 'yes':
        return 'ask_question'
    else:
        return "__end__"

# %% [markdown]
# ### Define Graph

# %%
graph = StateGraph(State)

# %%
graph.add_node('ask_question', ask_question)
graph.add_node("chatbot", chatbot)
graph.add_node('ask_another_question', ask_another_question)


graph.add_edge(START, "ask_question")
graph.add_edge('ask_question', "chatbot")
graph.add_edge('chatbot', 'ask_another_question')
graph.add_conditional_edges(source='ask_another_question', path=routing_function)

# %%
graph_compiled = graph.compile()

# %%
graph_compiled

# %%
graph_compiled.invoke(State(messages = []))
# Out:
#  --------> ENTERING ask_question:
#  What is the best car brand now days?
#  --------> ENTERING chatbot:
# ================================== Ai Message ==================================
#
# What is your question?
# ================================ Human Message =================================
#
# What is the best car brand now days?
# ================================== Ai Message ==================================
#
# Determining the "best" car brand can be subjective and depends on various factors such as personal preferences, budget, and specific needs (e.g., family, performance, fuel efficiency). That being said, here are some of the top-rated car brands in different categories:
#
# **Overall Quality and Reliability:**
#
# 1. Lexus - Known for their luxurious and reliable vehicles.
# 2. Toyota - Offers a wide range of models with excellent reliability and durability.
# 3. Porsche - Renowned for their high-performance and premium vehicles.
#
# **Luxury:**
#
# 1. Mercedes-Benz - Offers a wide range of luxury vehicles with advanced features.
# 2. BMW - Provides high-performance and stylish luxury cars.
# 3. Audi - Known for their sleek designs and advanced technology.
#
# **Electric and Hybrid:**
#
# 1. Tesla - Pioneers in electric vehicles, offering a range of models with impressive performance.
# 2. Hyundai/Kia - Offers affordable and feature-packed hybrid and electric vehicles.
# 3. Nissan - Provides a range of eco-friendly options, including the popular Leaf model.
#
# **Family-Friendly:**
#
# 1. Honda - Known for their reliable and practical family vehicles.
# 2. Toyota - Offers a wide range of models suitable for families, including the popular Highlander.
# 3. Subaru - Provides all-wheel-drive
#
#  --------> ENTERING ask_another_question:
# ================================== Ai Message ==================================
#
# What is your question?
# ================================ Human Message =================================
#
# What is the best car brand now days?
# ================================== Ai Message ==================================
#
# Determining the "best" car brand can be subjective and depends on various factors such as personal preferences, budget, and specific needs (e.g., family, performance, fuel efficiency). That being said, here are some of the top-rated car brands in different categories:
#
# **Overall Quality and Reliability:**
#
# 1. Lexus - Known for their luxurious and reliable vehicles.
# 2. Toyota - Offers a wide range of models with excellent reliability and durability.
# 3. Porsche - Renowned for their high-performance and premium vehicles.
#
# **Luxury:**
#
# 1. Mercedes-Benz - Offers a wide range of luxury vehicles with advanced features.
# 2. BMW - Provides high-performance and stylish luxury cars.
# 3. Audi - Known for their sleek designs and advanced technology.
#
# **Electric and Hybrid:**
#
# 1. Tesla - Pioneers in electric vehicles, offering a range of models with impressive performance.
# 2. Hyundai/Kia - Offers affordable and feature-packed hybrid and electric vehicles.
# 3. Nissan - Provides a range of eco-friendly options, including the popular Leaf model.
#
# **Family-Friendly:**
#
# 1. Honda - Known for their reliable and practical family vehicles.
# 2. Toyota - Offers a wide range of models suitable for families, including the popular Highlander.
# 3. Subaru - Provides all-wheel-drive
#  yes
#  --------> ENTERING ask_question:
# ================================== Ai Message ==================================
#
# What is your question?
# ================================ Human Message =================================
#
# What is the best car brand now days?
# ================================== Ai Message ==================================
#
# Determining the "best" car brand can be subjective and depends on various factors such as personal preferences, budget, and specific needs (e.g., family, performance, fuel efficiency). That being said, here are some of the top-rated car brands in different categories:
#
# **Overall Quality and Reliability:**
#
# 1. Lexus - Known for their luxurious and reliable vehicles.
# 2. Toyota - Offers a wide range of models with excellent reliability and durability.
# 3. Porsche - Renowned for their high-performance and premium vehicles.
#
# **Luxury:**
#
# 1. Mercedes-Benz - Offers a wide range of luxury vehicles with advanced features.
# 2. BMW - Provides high-performance and stylish luxury cars.
# 3. Audi - Known for their sleek designs and advanced technology.
#
# **Electric and Hybrid:**
#
# 1. Tesla - Pioneers in electric vehicles, offering a range of models with impressive performance.
# 2. Hyundai/Kia - Offers affordable and feature-packed hybrid and electric vehicles.
# 3. Nissan - Provides a range of eco-friendly options, including the popular Leaf model.
#
# **Family-Friendly:**
#
# 1. Honda - Known for their reliable and practical family vehicles.
# 2. Toyota - Offers a wide range of models suitable for families, including the popular Highlander.
# 3. Subaru - Provides all-wheel-drive
# ================================== Ai Message ==================================
#
# Would you like to ask one more question (yes/no)?
# ================================ Human Message =================================
#
# yes
#  what was my preveus question
#  --------> ENTERING chatbot:
# ================================== Ai Message ==================================
#
# What is your question?
# ================================ Human Message =================================
#
# What is the best car brand now days?
# ================================== Ai Message ==================================
#
# Determining the "best" car brand can be subjective and depends on various factors such as personal preferences, budget, and specific needs (e.g., family, performance, fuel efficiency). That being said, here are some of the top-rated car brands in different categories:
#
# **Overall Quality and Reliability:**
#
# 1. Lexus - Known for their luxurious and reliable vehicles.
# 2. Toyota - Offers a wide range of models with excellent reliability and durability.
# 3. Porsche - Renowned for their high-performance and premium vehicles.
#
# **Luxury:**
#
# 1. Mercedes-Benz - Offers a wide range of luxury vehicles with advanced features.
# 2. BMW - Provides high-performance and stylish luxury cars.
# 3. Audi - Known for their sleek designs and advanced technology.
#
# **Electric and Hybrid:**
#
# 1. Tesla - Pioneers in electric vehicles, offering a range of models with impressive performance.
# 2. Hyundai/Kia - Offers affordable and feature-packed hybrid and electric vehicles.
# 3. Nissan - Provides a range of eco-friendly options, including the popular Leaf model.
#
# **Family-Friendly:**
#
# 1. Honda - Known for their reliable and practical family vehicles.
# 2. Toyota - Offers a wide range of models suitable for families, including the popular Highlander.
# 3. Subaru - Provides all-wheel-drive
# ================================== Ai Message ==================================
#
# Would you like to ask one more question (yes/no)?
# ================================ Human Message =================================
#
# yes
# ================================== Ai Message ==================================
#
# What is your question?
# ================================ Human Message =================================
#
# what was my preveus question
# ================================== Ai Message ==================================
#
# Your previous question was: "What is the best car brand now days?"
#
#  --------> ENTERING ask_another_question:
# ================================== Ai Message ==================================
#
# What is your question?
# ================================ Human Message =================================
#
# What is the best car brand now days?
# ================================== Ai Message ==================================
#
# Determining the "best" car brand can be subjective and depends on various factors such as personal preferences, budget, and specific needs (e.g., family, performance, fuel efficiency). That being said, here are some of the top-rated car brands in different categories:
#
# **Overall Quality and Reliability:**
#
# 1. Lexus - Known for their luxurious and reliable vehicles.
# 2. Toyota - Offers a wide range of models with excellent reliability and durability.
# 3. Porsche - Renowned for their high-performance and premium vehicles.
#
# **Luxury:**
#
# 1. Mercedes-Benz - Offers a wide range of luxury vehicles with advanced features.
# 2. BMW - Provides high-performance and stylish luxury cars.
# 3. Audi - Known for their sleek designs and advanced technology.
#
# **Electric and Hybrid:**
#
# 1. Tesla - Pioneers in electric vehicles, offering a range of models with impressive performance.
# 2. Hyundai/Kia - Offers affordable and feature-packed hybrid and electric vehicles.
# 3. Nissan - Provides a range of eco-friendly options, including the popular Leaf model.
#
# **Family-Friendly:**
#
# 1. Honda - Known for their reliable and practical family vehicles.
# 2. Toyota - Offers a wide range of models suitable for families, including the popular Highlander.
# 3. Subaru - Provides all-wheel-drive
# ================================== Ai Message ==================================
#
# Would you like to ask one more question (yes/no)?
# ================================ Human Message =================================
#
# yes
# ================================== Ai Message ==================================
#
# What is your question?
# ================================ Human Message =================================
#
# what was my preveus question
# ================================== Ai Message ==================================
#
# Your previous question was: "What is the best car brand now days?"
#  no
# {'messages': [AIMessage(content='What is your question?', additional_kwargs={}, response_metadata={}, id='902c569b-f36c-491a-9082-68565e9f3701'),
#   HumanMessage(content='What is the best car brand now days?', additional_kwargs={}, response_metadata={}, id='403fe658-aa36-4cf6-b525-f1c7c2d2f323'),
#   AIMessage(content='Determining the "best" car brand can be subjective and depends on various factors such as personal preferences, budget, and specific needs (e.g., family, performance, fuel efficiency). That being said, here are some of the top-rated car brands in different categories:\n\n**Overall Quality and Reliability:**\n\n1. Lexus - Known for their luxurious and reliable vehicles.\n2. Toyota - Offers a wide range of models with excellent reliability and durability.\n3. Porsche - Renowned for their high-performance and premium vehicles.\n\n**Luxury:**\n\n1. Mercedes-Benz - Offers a wide range of luxury vehicles with advanced features.\n2. BMW - Provides high-performance and stylish luxury cars.\n3. Audi - Known for their sleek designs and advanced technology.\n\n**Electric and Hybrid:**\n\n1. Tesla - Pioneers in electric vehicles, offering a range of models with impressive performance.\n2. Hyundai/Kia - Offers affordable and feature-packed hybrid and electric vehicles.\n3. Nissan - Provides a range of eco-friendly options, including the popular Leaf model.\n\n**Family-Friendly:**\n\n1. Honda - Known for their reliable and practical family vehicles.\n2. Toyota - Offers a wide range of models suitable for families, including the popular Highlander.\n3. Subaru - Provides all-wheel-drive', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2025-09-30T15:30:25.792274Z', 'done': True, 'done_reason': 'length', 'total_duration': 7763777459, 'load_duration': 2039342959, 'prompt_eval_count': 44, 'prompt_eval_duration': 471343292, 'eval_count': 256, 'eval_duration': 5249400542, 'model_name': 'llama3.2'}, id='run--d948c244-2497-4078-9b66-5d284b018a13-0', usage_metadata={'input_tokens': 44, 'output_tokens': 256, 'total_tokens': 300}),
#   AIMessage(content='Would you like to ask one more question (yes/no)?', additional_kwargs={}, response_metadata={}, id='4e728696-c30b-4db2-b028-4ddeba4ef9d9'),
#   HumanMessage(content='yes', additional_kwargs={}, response_metadata={}, id='0aa792f3-afe4-4e46-83d7-b7b16e2c2552'),
#   AIMessage(content='What is your question?', additional_kwargs={}, response_metadata={}, id='a7375dec-3c95-4c39-8216-7c45d11cb640'),
#   HumanMessage(content='what was my preveus question', additional_kwargs={}, response_metadata={}, id='9b722867-3bb0-4810-86f8-3d6d0aed991c'),
#   AIMessage(content='Your previous question was: "What is the best car brand now days?"', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2025-09-30T15:32:23.891345Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1196366375, 'load_duration': 96815542, 'prompt_eval_count': 346, 'prompt_eval_duration': 769598125, 'eval_count': 16, 'eval_duration': 323133625, 'model_name': 'llama3.2'}, id='run--c7884e65-074c-4aed-b03b-46ef69efcbef-0', usage_metadata={'input_tokens': 346, 'output_tokens': 16, 'total_tokens': 362}),
#   AIMessage(content='Would you like to ask one more question (yes/no)?', additional_kwargs={}, response_metadata={}, id='c5c69ccb-fa8a-4938-92aa-acfa7898f4b5'),
#   HumanMessage(content='no', additional_kwargs={}, response_metadata={}, id='3b4724e0-d919-4af7-a1a3-37ff74b3a821')]}
